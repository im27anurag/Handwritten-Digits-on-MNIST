# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow.keras.datasets.mnist as mnist
(features_train, label_train), (features_test, label_test) = \
mnist.load_data()

label_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
features_train.shape
# Out:
# (60000, 28, 28)

# %%
features_test.shape
# Out:
# (10000, 28, 28)

# %%
features_train = features_train.reshape(60000, 28, 28, 1)
features_test = features_test.reshape(10000, 28, 28, 1)
from tensorflow.keras import layers
import numpy as np
np.random.seed(8)
tf.random.set_seed(8)

# %%
model = tf.keras.Sequential()
conv_layer1 = layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1))
conv_layer2 = layers.Conv2D(64, (3,3), activation='relu')
fc_layer1 = layers.Dense(128, activation='relu')
fc_layer2 = layers.Dense(10, activation='softmax')

# %%
model.add(conv_layer1)
model.add(layers.MaxPooling2D(2, 2))
model.add(conv_layer2)
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Flatten())
model.add(fc_layer1)
model.add(fc_layer2)
optimizer = tf.keras.optimizers.Adam(0.001)

# %%
model.compile(loss='sparse_categorical_crossentropy', \
optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               204928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(features_train, label_train, epochs=5,\
validation_split = 0.2, verbose=2)
# Out:
# Epoch 1/5
# 1500/1500 - 64s - loss: 0.2814 - accuracy: 0.9510 - val_loss: 0.0936 - val_accuracy: 0.9750
# Epoch 2/5
# 1500/1500 - 63s - loss: 0.0615 - accuracy: 0.9810 - val_loss: 0.0621 - val_accuracy: 0.9827
# Epoch 3/5
# 1500/1500 - 63s - loss: 0.0464 - accuracy: 0.9860 - val_loss: 0.0525 - val_accuracy: 0.9843
# Epoch 4/5
# 1500/1500 - 65s - loss: 0.0399 - accuracy: 0.9877 - val_loss: 0.0541 - val_accuracy: 0.9843
# Epoch 5/5
# 1500/1500 - 66s - loss: 0.0346 - accuracy: 0.9892 - val_loss: 0.0679 - val_accuracy: 0.9853

# %%
model.evaluate(features_test, label_test)
# Out:
# 313/313 [==============================] - 5s 14ms/step - loss: 0.0619 - accuracy: 0.9845
# [0.06190139800310135, 0.984499990940094]

# %%
loc = 2000
test_image = features_test[loc]
test_image.shape
# Out:
# (28, 28, 1)

# %%
test_image = test_image.reshape(1,28,28,1)
result = model.predict(test_image)
result.argmax()
label_test[loc]
plt.imshow(features_test[loc])
